# %%
import pandas as pd

df=pd.read_json(r"D:\Downloads\My code\NASA-Asteroid-Classifier\data\raw_data.json")
print(df.head())
# Out:
#         id                name  absolute_magnitude   velocity  diameter_min  \
# 0  3753662           (2016 LT)               21.53   9.514823      0.131388
# 1  3838186          (2019 CN2)               28.40  10.194522      0.005553
# 2  3842766          (2019 LQ1)               26.10  13.991209      0.016016
# 3  2322756  322756 (2001 CK32)               19.23  16.103616      0.378926
# 4  3655548         (2013 YA38)               21.02  21.326060      0.166171
#
#    diameter_max  miss_distance_au  is_hazardous
# 0      0.293792          0.066124         False
# 1      0.012418          0.313375         False
# 2      0.035813          0.190037         False
# 3      0.847305          0.489369         False
# 4      0.371569          0.147307         False

# %%
df["velocity"]=df["velocity"].astype(float)
df["miss_distance_au"]=df["miss_distance_au"].astype(float)
print(df.head())
# Out:
#         id                name  absolute_magnitude   velocity  diameter_min  \
# 0  3753662           (2016 LT)               21.53   9.514823      0.131388
# 1  3838186          (2019 CN2)               28.40  10.194522      0.005553
# 2  3842766          (2019 LQ1)               26.10  13.991209      0.016016
# 3  2322756  322756 (2001 CK32)               19.23  16.103616      0.378926
# 4  3655548         (2013 YA38)               21.02  21.326060      0.166171
#
#    diameter_max  miss_distance_au  is_hazardous
# 0      0.293792          0.066124         False
# 1      0.012418          0.313375         False
# 2      0.035813          0.190037         False
# 3      0.847305          0.489369         False
# 4      0.371569          0.147307         False

# %%
final_df=df.drop(columns=["id","name"])
print(final_df.head())
# Out:
#    absolute_magnitude   velocity  diameter_min  diameter_max  \
# 0               21.53   9.514823      0.131388      0.293792
# 1               28.40  10.194522      0.005553      0.012418
# 2               26.10  13.991209      0.016016      0.035813
# 3               19.23  16.103616      0.378926      0.847305
# 4               21.02  21.326060      0.166171      0.371569
#
#    miss_distance_au  is_hazardous
# 0          0.066124         False
# 1          0.313375         False
# 2          0.190037         False
# 3          0.489369         False
# 4          0.147307         False

# %%
final_df["is_hazardous"]=final_df["is_hazardous"].astype(int)
print(final_df.head())
# Out:
#    absolute_magnitude   velocity  diameter_min  diameter_max  \
# 0               21.53   9.514823      0.131388      0.293792
# 1               28.40  10.194522      0.005553      0.012418
# 2               26.10  13.991209      0.016016      0.035813
# 3               19.23  16.103616      0.378926      0.847305
# 4               21.02  21.326060      0.166171      0.371569
#
#    miss_distance_au  is_hazardous
# 0          0.066124             0
# 1          0.313375             0
# 2          0.190037             0
# 3          0.489369             0
# 4          0.147307             0

# %%
final_df.to_csv(r"D:\Downloads\My code\NASA-Asteroid-Classifier\data\cleaned_data.csv",index=False)

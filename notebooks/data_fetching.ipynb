# %%
import requests
import json
import os
from datetime import date, datetime, timedelta
date=date(2006, 9, 4)
datetime=datetime(2006, 9, 4, 7,20,0)
print(date)
print(datetime)
print(date.month)
print(datetime.second)
# Out:
# 2006-09-04
# 2006-09-04 07:20:00
# 9
# 0

# %%
from datetime import date, datetime, timedelta
start=date(2006, 9, 4)
end=date(2006, 9, 14)
one_week=timedelta(days=7)
next_week=start+one_week
print(next_week)
x=end-one_week
print(x)
# Out:
# 2006-09-11
# 2006-09-07

# %%
import os
from dotenv import load_dotenv
load_dotenv()
api_key=os.getenv("API_key")
# Out:
# OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW

# %%
import os
from dotenv import load_dotenv
import requests
import json


load_dotenv()
api_key=os.getenv("API_key")

url="https://api.nasa.gov/neo/rest/v1/feed"

params={
    "start_date":"2026-06-01",
    "end_date":"2026-06-07",
    "api_key":api_key
}

response=requests.get(url,params=params)



if response.status_code==200:
    
    data = response.json()
    print(json.dumps(data,indent=2))
    print("SUCCESS")
elif response.status_code==429:
    print("Rate limit hit")
elif response.status_code==500:
    print("Server down")
else:
    print(f"Unexpected error {response.status_code}")
# Out:
# {
#   "links": {
#     "next": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2026-06-07&end_date=2026-06-13&detailed=false&api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW",
#     "previous": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2026-05-26&end_date=2026-06-01&detailed=false&api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW",
#     "self": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2026-06-01&end_date=2026-06-07&detailed=false&api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#   },
#   "element_count": 30,
#   "near_earth_objects": {
#     "2026-06-03": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/2437844?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "2437844",
#         "neo_reference_id": "2437844",
#         "name": "437844 (1999 MN)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2437844",
#         "absolute_magnitude_h": 21.01,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1669379118,
#             "estimated_diameter_max": 0.3732845187
#           },
#           "meters": {
#             "estimated_diameter_min": 166.9379117726,
#             "estimated_diameter_max": 373.2845187454
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1037303772,
#             "estimated_diameter_max": 0.2319481747
#           },
#           "feet": {
#             "estimated_diameter_min": 547.69657846,
#             "estimated_diameter_max": 1224.6867804805
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-03",
#             "close_approach_date_full": "2026-Jun-03 06:26",
#             "epoch_date_close_approach": 1780467960000,
#             "relative_velocity": {
#               "kilometers_per_second": "20.5789449268",
#               "kilometers_per_hour": "74084.2017363763",
#               "miles_per_hour": "46033.0419066945"
#             },
#             "miss_distance": {
#               "astronomical": "0.1615567231",
#               "lunar": "62.8455652859",
#               "kilometers": "24168541.659939797",
#               "miles": "15017635.4104793186"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3698472?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3698472",
#         "neo_reference_id": "3698472",
#         "name": "(2014 WD201)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3698472",
#         "absolute_magnitude_h": 19.2,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3841978911,
#             "estimated_diameter_max": 0.8590926012
#           },
#           "meters": {
#             "estimated_diameter_min": 384.1978910643,
#             "estimated_diameter_max": 859.0926012318
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2387294278,
#             "estimated_diameter_max": 0.5338152287
#           },
#           "feet": {
#             "estimated_diameter_min": 1260.4918089193,
#             "estimated_diameter_max": 2818.5453698252
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-03",
#             "close_approach_date_full": "2026-Jun-03 11:45",
#             "epoch_date_close_approach": 1780487100000,
#             "relative_velocity": {
#               "kilometers_per_second": "19.974695315",
#               "kilometers_per_hour": "71908.9031340223",
#               "miles_per_hour": "44681.3959501374"
#             },
#             "miss_distance": {
#               "astronomical": "0.4448614167",
#               "lunar": "173.0510910963",
#               "kilometers": "66550320.383502429",
#               "miles": "41352451.5476503602"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3836085?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3836085",
#         "neo_reference_id": "3836085",
#         "name": "(2018 VQ3)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3836085",
#         "absolute_magnitude_h": 20.55,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.2063264836,
#             "estimated_diameter_max": 0.4613600429
#           },
#           "meters": {
#             "estimated_diameter_min": 206.3264835999,
#             "estimated_diameter_max": 461.3600428879
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1282052934,
#             "estimated_diameter_max": 0.2866757512
#           },
#           "feet": {
#             "estimated_diameter_min": 676.9241804539,
#             "estimated_diameter_max": 1513.6484831083
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-03",
#             "close_approach_date_full": "2026-Jun-03 02:52",
#             "epoch_date_close_approach": 1780455120000,
#             "relative_velocity": {
#               "kilometers_per_second": "18.3663159671",
#               "kilometers_per_hour": "66118.7374815604",
#               "miles_per_hour": "41083.6121868062"
#             },
#             "miss_distance": {
#               "astronomical": "0.149966159",
#               "lunar": "58.336835851",
#               "kilometers": "22434617.95848133",
#               "miles": "13940225.182569154"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3843765?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3843765",
#         "neo_reference_id": "3843765",
#         "name": "(2019 RH)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843765",
#         "absolute_magnitude_h": 26.0,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0167708462,
#             "estimated_diameter_max": 0.0375007522
#           },
#           "meters": {
#             "estimated_diameter_min": 16.7708462163,
#             "estimated_diameter_max": 37.5007521798
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0104209175,
#             "estimated_diameter_max": 0.0233018799
#           },
#           "feet": {
#             "estimated_diameter_min": 55.0224631002,
#             "estimated_diameter_max": 123.0339677816
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-03",
#             "close_approach_date_full": "2026-Jun-03 17:05",
#             "epoch_date_close_approach": 1780506300000,
#             "relative_velocity": {
#               "kilometers_per_second": "11.9809958403",
#               "kilometers_per_hour": "43131.585025102",
#               "miles_per_hour": "26800.2895951807"
#             },
#             "miss_distance": {
#               "astronomical": "0.4357877517",
#               "lunar": "169.5214354113",
#               "kilometers": "65192919.426408879",
#               "miles": "40509001.7042013702"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-02": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/2141531?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "2141531",
#         "neo_reference_id": "2141531",
#         "name": "141531 (2002 GB)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2141531",
#         "absolute_magnitude_h": 19.15,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3931470096,
#             "estimated_diameter_max": 0.8791034386
#           },
#           "meters": {
#             "estimated_diameter_min": 393.1470095751,
#             "estimated_diameter_max": 879.1034385607
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2442901505,
#             "estimated_diameter_max": 0.5462493827
#           },
#           "feet": {
#             "estimated_diameter_min": 1289.8524348944,
#             "estimated_diameter_max": 2884.1977253675
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 23:26",
#             "epoch_date_close_approach": 1780442760000,
#             "relative_velocity": {
#               "kilometers_per_second": "14.6036159258",
#               "kilometers_per_hour": "52573.0173327108",
#               "miles_per_hour": "32666.8284643169"
#             },
#             "miss_distance": {
#               "astronomical": "0.4665729321",
#               "lunar": "181.4968705869",
#               "kilometers": "69798316.841814627",
#               "miles": "43370662.9611387726"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3410171?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3410171",
#         "neo_reference_id": "3410171",
#         "name": "(2008 JV2)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3410171",
#         "absolute_magnitude_h": 24.7,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0305179233,
#             "estimated_diameter_max": 0.0682401509
#           },
#           "meters": {
#             "estimated_diameter_min": 30.5179232594,
#             "estimated_diameter_max": 68.2401509401
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0189629525,
#             "estimated_diameter_max": 0.0424024508
#           },
#           "feet": {
#             "estimated_diameter_min": 100.1244233463,
#             "estimated_diameter_max": 223.8850168104
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 23:16",
#             "epoch_date_close_approach": 1780442160000,
#             "relative_velocity": {
#               "kilometers_per_second": "22.5085098886",
#               "kilometers_per_hour": "81030.6355990453",
#               "miles_per_hour": "50349.2857698624"
#             },
#             "miss_distance": {
#               "astronomical": "0.4992354475",
#               "lunar": "194.2025890775",
#               "kilometers": "74684559.574496825",
#               "miles": "46406833.406133185"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3428531?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3428531",
#         "neo_reference_id": "3428531",
#         "name": "(2008 SY150)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3428531",
#         "absolute_magnitude_h": 24.7,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0305179233,
#             "estimated_diameter_max": 0.0682401509
#           },
#           "meters": {
#             "estimated_diameter_min": 30.5179232594,
#             "estimated_diameter_max": 68.2401509401
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0189629525,
#             "estimated_diameter_max": 0.0424024508
#           },
#           "feet": {
#             "estimated_diameter_min": 100.1244233463,
#             "estimated_diameter_max": 223.8850168104
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 23:40",
#             "epoch_date_close_approach": 1780443600000,
#             "relative_velocity": {
#               "kilometers_per_second": "10.531450981",
#               "kilometers_per_hour": "37913.2235314312",
#               "miles_per_hour": "23557.802699294"
#             },
#             "miss_distance": {
#               "astronomical": "0.1453270055",
#               "lunar": "56.5322051395",
#               "kilometers": "21740610.476278285",
#               "miles": "13508988.929818933"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3553284?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3553284",
#         "neo_reference_id": "3553284",
#         "name": "(2010 XD25)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3553284",
#         "absolute_magnitude_h": 20.76,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1873074177,
#             "estimated_diameter_max": 0.4188321187
#           },
#           "meters": {
#             "estimated_diameter_min": 187.3074177315,
#             "estimated_diameter_max": 418.8321187375
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1163873975,
#             "estimated_diameter_max": 0.2602501325
#           },
#           "feet": {
#             "estimated_diameter_min": 614.5256683901,
#             "estimated_diameter_max": 1374.1211684388
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 07:01",
#             "epoch_date_close_approach": 1780383660000,
#             "relative_velocity": {
#               "kilometers_per_second": "29.0690868658",
#               "kilometers_per_hour": "104648.7127168764",
#               "miles_per_hour": "65024.6404101058"
#             },
#             "miss_distance": {
#               "astronomical": "0.4222820639",
#               "lunar": "164.2677228571",
#               "kilometers": "63172497.298643893",
#               "miles": "39253569.6091680034"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3579625?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3579625",
#         "neo_reference_id": "3579625",
#         "name": "(2011 SF108)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3579625",
#         "absolute_magnitude_h": 20.06,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.2585562121,
#             "estimated_diameter_max": 0.5781492662
#           },
#           "meters": {
#             "estimated_diameter_min": 258.5562120799,
#             "estimated_diameter_max": 578.1492662155
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1606593321,
#             "estimated_diameter_max": 0.3592451877
#           },
#           "feet": {
#             "estimated_diameter_min": 848.2815628403,
#             "estimated_diameter_max": 1896.8152385706
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 18:53",
#             "epoch_date_close_approach": 1780426380000,
#             "relative_velocity": {
#               "kilometers_per_second": "15.6630725114",
#               "kilometers_per_hour": "56387.0610409745",
#               "miles_per_hour": "35036.7269007099"
#             },
#             "miss_distance": {
#               "astronomical": "0.4377050035",
#               "lunar": "170.2672463615",
#               "kilometers": "65479736.211942545",
#               "miles": "40687221.390575321"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3678630?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3678630",
#         "neo_reference_id": "3678630",
#         "name": "(2014 OL339)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3678630",
#         "absolute_magnitude_h": 22.78,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0738847787,
#             "estimated_diameter_max": 0.1652113876
#           },
#           "meters": {
#             "estimated_diameter_min": 73.884778657,
#             "estimated_diameter_max": 165.2113875797
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0459098588,
#             "estimated_diameter_max": 0.1026575651
#           },
#           "feet": {
#             "estimated_diameter_min": 242.4041372092,
#             "estimated_diameter_max": 542.0321288269
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 18:15",
#             "epoch_date_close_approach": 1780424100000,
#             "relative_velocity": {
#               "kilometers_per_second": "11.8622601181",
#               "kilometers_per_hour": "42704.1364253353",
#               "miles_per_hour": "26534.6896582868"
#             },
#             "miss_distance": {
#               "astronomical": "0.3412333442",
#               "lunar": "132.7397708938",
#               "kilometers": "51047781.465296854",
#               "miles": "31719620.5441864252"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3884238?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3884238",
#         "neo_reference_id": "3884238",
#         "name": "(2019 US10)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3884238",
#         "absolute_magnitude_h": 20.68,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1943367684,
#             "estimated_diameter_max": 0.4345502246
#           },
#           "meters": {
#             "estimated_diameter_min": 194.3367683899,
#             "estimated_diameter_max": 434.5502246474
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1207552321,
#             "estimated_diameter_max": 0.2700169076
#           },
#           "feet": {
#             "estimated_diameter_min": 637.5878432043,
#             "estimated_diameter_max": 1425.6897590323
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 02:32",
#             "epoch_date_close_approach": 1780367520000,
#             "relative_velocity": {
#               "kilometers_per_second": "14.2682462176",
#               "kilometers_per_hour": "51365.6863835191",
#               "miles_per_hour": "31916.6399642483"
#             },
#             "miss_distance": {
#               "astronomical": "0.3893958238",
#               "lunar": "151.4749754582",
#               "kilometers": "58252785.827375306",
#               "miles": "36196602.6543629828"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-01": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3774363?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3774363",
#         "neo_reference_id": "3774363",
#         "name": "(2017 HE49)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3774363",
#         "absolute_magnitude_h": 23.7,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0483676488,
#             "estimated_diameter_max": 0.1081533507
#           },
#           "meters": {
#             "estimated_diameter_min": 48.3676488219,
#             "estimated_diameter_max": 108.1533506775
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0300542543,
#             "estimated_diameter_max": 0.0672033557
#           },
#           "feet": {
#             "estimated_diameter_min": 158.6865169607,
#             "estimated_diameter_max": 354.8338390368
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-01",
#             "close_approach_date_full": "2026-Jun-01 10:15",
#             "epoch_date_close_approach": 1780308900000,
#             "relative_velocity": {
#               "kilometers_per_second": "4.4192793323",
#               "kilometers_per_hour": "15909.4055963739",
#               "miles_per_hour": "9885.4859384802"
#             },
#             "miss_distance": {
#               "astronomical": "0.1707317045",
#               "lunar": "66.4146330505",
#               "kilometers": "25541099.334669415",
#               "miles": "15870503.201551327"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3795028?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3795028",
#         "neo_reference_id": "3795028",
#         "name": "(2017 YV3)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3795028",
#         "absolute_magnitude_h": 25.0,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.02658,
#             "estimated_diameter_max": 0.0594346868
#           },
#           "meters": {
#             "estimated_diameter_min": 26.58,
#             "estimated_diameter_max": 59.4346868419
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0165160412,
#             "estimated_diameter_max": 0.0369309908
#           },
#           "feet": {
#             "estimated_diameter_min": 87.2047272,
#             "estimated_diameter_max": 194.9956979785
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-01",
#             "close_approach_date_full": "2026-Jun-01 16:42",
#             "epoch_date_close_approach": 1780332120000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.5515259013",
#               "kilometers_per_hour": "23585.4932445653",
#               "miles_per_hour": "14655.1082885467"
#             },
#             "miss_distance": {
#               "astronomical": "0.2627561175",
#               "lunar": "102.2121297075",
#               "kilometers": "39307755.507469725",
#               "miles": "24424706.683643205"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3836092?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3836092",
#         "neo_reference_id": "3836092",
#         "name": "(2018 VO3)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3836092",
#         "absolute_magnitude_h": 27.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0101054342,
#             "estimated_diameter_max": 0.0225964377
#           },
#           "meters": {
#             "estimated_diameter_min": 10.1054341542,
#             "estimated_diameter_max": 22.5964377109
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0062792237,
#             "estimated_diameter_max": 0.0140407711
#           },
#           "feet": {
#             "estimated_diameter_min": 33.1543125905,
#             "estimated_diameter_max": 74.1352966996
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-01",
#             "close_approach_date_full": "2026-Jun-01 10:29",
#             "epoch_date_close_approach": 1780309740000,
#             "relative_velocity": {
#               "kilometers_per_second": "5.4485213414",
#               "kilometers_per_hour": "19614.6768290682",
#               "miles_per_hour": "12187.7973885952"
#             },
#             "miss_distance": {
#               "astronomical": "0.2646063846",
#               "lunar": "102.9318836094",
#               "kilometers": "39584551.524560802",
#               "miles": "24596699.7532389876"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-07": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3336867?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3336867",
#         "neo_reference_id": "3336867",
#         "name": "(2006 MB)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3336867",
#         "absolute_magnitude_h": 22.59,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0806408277,
#             "estimated_diameter_max": 0.1803183724
#           },
#           "meters": {
#             "estimated_diameter_min": 80.6408276759,
#             "estimated_diameter_max": 180.3183724451
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0501078717,
#             "estimated_diameter_max": 0.1120446074
#           },
#           "feet": {
#             "estimated_diameter_min": 264.5696530721,
#             "estimated_diameter_max": 591.5957290529
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-07",
#             "close_approach_date_full": "2026-Jun-07 09:44",
#             "epoch_date_close_approach": 1780825440000,
#             "relative_velocity": {
#               "kilometers_per_second": "7.3333208459",
#               "kilometers_per_hour": "26399.9550453693",
#               "miles_per_hour": "16403.905400274"
#             },
#             "miss_distance": {
#               "astronomical": "0.1009440019",
#               "lunar": "39.2672167391",
#               "kilometers": "15101007.673515953",
#               "miles": "9383331.0574800314"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3802390?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3802390",
#         "neo_reference_id": "3802390",
#         "name": "(2018 GE)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3802390",
#         "absolute_magnitude_h": 27.5,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.008405334,
#             "estimated_diameter_max": 0.0187948982
#           },
#           "meters": {
#             "estimated_diameter_min": 8.4053340207,
#             "estimated_diameter_max": 18.7948982439
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0052228308,
#             "estimated_diameter_max": 0.0116786047
#           },
#           "feet": {
#             "estimated_diameter_min": 27.5765560686,
#             "estimated_diameter_max": 61.6630539546
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-07",
#             "close_approach_date_full": "2026-Jun-07 14:05",
#             "epoch_date_close_approach": 1780841100000,
#             "relative_velocity": {
#               "kilometers_per_second": "3.0944487127",
#               "kilometers_per_hour": "11140.0153655584",
#               "miles_per_hour": "6921.9723253382"
#             },
#             "miss_distance": {
#               "astronomical": "0.0418956903",
#               "lunar": "16.2974235267",
#               "kilometers": "6267506.031059661",
#               "miles": "3894447.6597628818"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": true,
#         "sentry_data": "http://api.nasa.gov/neo/rest/v1/neo/sentry/3802390?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3838104?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3838104",
#         "neo_reference_id": "3838104",
#         "name": "(2019 CH1)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838104",
#         "absolute_magnitude_h": 21.22,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1515496636,
#             "estimated_diameter_max": 0.3388753497
#           },
#           "meters": {
#             "estimated_diameter_min": 151.5496635722,
#             "estimated_diameter_max": 338.8753497147
#           },
#           "miles": {
#             "estimated_diameter_min": 0.094168566,
#             "estimated_diameter_max": 0.2105673149
#           },
#           "feet": {
#             "estimated_diameter_min": 497.2101982343,
#             "estimated_diameter_max": 1111.795802358
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-07",
#             "close_approach_date_full": "2026-Jun-07 08:14",
#             "epoch_date_close_approach": 1780820040000,
#             "relative_velocity": {
#               "kilometers_per_second": "21.8900781055",
#               "kilometers_per_hour": "78804.2811796736",
#               "miles_per_hour": "48965.9157141144"
#             },
#             "miss_distance": {
#               "astronomical": "0.1578444104",
#               "lunar": "61.4014756456",
#               "kilometers": "23613187.587245848",
#               "miles": "14672554.3913267824"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3991612?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3991612",
#         "neo_reference_id": "3991612",
#         "name": "(2020 DJ)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3991612",
#         "absolute_magnitude_h": 26.2,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0152951935,
#             "estimated_diameter_max": 0.0342010925
#           },
#           "meters": {
#             "estimated_diameter_min": 15.2951935344,
#             "estimated_diameter_max": 34.201092472
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0095039897,
#             "estimated_diameter_max": 0.021251567
#           },
#           "feet": {
#             "estimated_diameter_min": 50.1810827555,
#             "estimated_diameter_max": 112.2083122258
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-07",
#             "close_approach_date_full": "2026-Jun-07 05:49",
#             "epoch_date_close_approach": 1780811340000,
#             "relative_velocity": {
#               "kilometers_per_second": "5.4696246188",
#               "kilometers_per_hour": "19690.6486275341",
#               "miles_per_hour": "12235.0033097031"
#             },
#             "miss_distance": {
#               "astronomical": "0.4019967606",
#               "lunar": "156.3767398734",
#               "kilometers": "60137859.132659922",
#               "miles": "37367932.8909620436"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-06": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/2478784?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "2478784",
#         "neo_reference_id": "2478784",
#         "name": "478784 (2012 UV136)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2478784",
#         "absolute_magnitude_h": 25.6,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0201629919,
#             "estimated_diameter_max": 0.0450858206
#           },
#           "meters": {
#             "estimated_diameter_min": 20.1629919443,
#             "estimated_diameter_max": 45.0858206172
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0125286985,
#             "estimated_diameter_max": 0.0280150214
#           },
#           "feet": {
#             "estimated_diameter_min": 66.1515504905,
#             "estimated_diameter_max": 147.9193637137
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 16:56",
#             "epoch_date_close_approach": 1780764960000,
#             "relative_velocity": {
#               "kilometers_per_second": "16.0783776861",
#               "kilometers_per_hour": "57882.1596699298",
#               "miles_per_hour": "35965.7230460183"
#             },
#             "miss_distance": {
#               "astronomical": "0.4165825079",
#               "lunar": "162.0505955731",
#               "kilometers": "62319855.861098173",
#               "miles": "38723762.7873458674"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3304382?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3304382",
#         "neo_reference_id": "3304382",
#         "name": "(2005 WR2)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3304382",
#         "absolute_magnitude_h": 19.52,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3315545381,
#             "estimated_diameter_max": 0.7413784854
#           },
#           "meters": {
#             "estimated_diameter_min": 331.5545380858,
#             "estimated_diameter_max": 741.3784854083
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2060183749,
#             "estimated_diameter_max": 0.4606710909
#           },
#           "feet": {
#             "estimated_diameter_min": 1087.7773907333,
#             "estimated_diameter_max": 2432.3441900671
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 20:30",
#             "epoch_date_close_approach": 1780777800000,
#             "relative_velocity": {
#               "kilometers_per_second": "14.4751788763",
#               "kilometers_per_hour": "52110.6439547264",
#               "miles_per_hour": "32379.5276284243"
#             },
#             "miss_distance": {
#               "astronomical": "0.0997712288",
#               "lunar": "38.8110080032",
#               "kilometers": "14925563.315762656",
#               "miles": "9274314.9887144128"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3644087?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3644087",
#         "neo_reference_id": "3644087",
#         "name": "(2013 MR)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3644087",
#         "absolute_magnitude_h": 21.62,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1260535197,
#             "estimated_diameter_max": 0.2818642388
#           },
#           "meters": {
#             "estimated_diameter_min": 126.0535196822,
#             "estimated_diameter_max": 281.8642388124
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0783260016,
#             "estimated_diameter_max": 0.1751422639
#           },
#           "feet": {
#             "estimated_diameter_min": 413.5614295141,
#             "estimated_diameter_max": 924.7514692654
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 08:36",
#             "epoch_date_close_approach": 1780734960000,
#             "relative_velocity": {
#               "kilometers_per_second": "17.3402140505",
#               "kilometers_per_hour": "62424.7705816326",
#               "miles_per_hour": "38788.3248094594"
#             },
#             "miss_distance": {
#               "astronomical": "0.1122679098",
#               "lunar": "43.6722169122",
#               "kilometers": "16795040.175432126",
#               "miles": "10435954.0433942988"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3892162?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3892162",
#         "neo_reference_id": "3892162",
#         "name": "(2019 UK13)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3892162",
#         "absolute_magnitude_h": 24.71,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0303777061,
#             "estimated_diameter_max": 0.0679266159
#           },
#           "meters": {
#             "estimated_diameter_min": 30.3777061387,
#             "estimated_diameter_max": 67.9266159267
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0188758256,
#             "estimated_diameter_max": 0.0422076293
#           },
#           "feet": {
#             "estimated_diameter_min": 99.6643934081,
#             "estimated_diameter_max": 222.8563585969
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 06:51",
#             "epoch_date_close_approach": 1780728660000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.0591186198",
#               "kilometers_per_hour": "21812.8270311597",
#               "miles_per_hour": "13553.6424405558"
#             },
#             "miss_distance": {
#               "astronomical": "0.3950304344",
#               "lunar": "153.6668389816",
#               "kilometers": "59095711.571414728",
#               "miles": "36720372.4241821264"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/2662203?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "2662203",
#         "neo_reference_id": "2662203",
#         "name": "662203 (2005 WR2)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2662203",
#         "absolute_magnitude_h": 19.47,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3392774354,
#             "estimated_diameter_max": 0.7586474087
#           },
#           "meters": {
#             "estimated_diameter_min": 339.2774353821,
#             "estimated_diameter_max": 758.6474087461
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2108171593,
#             "estimated_diameter_max": 0.471401499
#           },
#           "feet": {
#             "estimated_diameter_min": 1113.1149810989,
#             "estimated_diameter_max": 2489.0007645105
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 20:30",
#             "epoch_date_close_approach": 1780777800000,
#             "relative_velocity": {
#               "kilometers_per_second": "14.4751730434",
#               "kilometers_per_hour": "52110.622956137",
#               "miles_per_hour": "32379.5145807175"
#             },
#             "miss_distance": {
#               "astronomical": "0.0997713286",
#               "lunar": "38.8110468254",
#               "kilometers": "14925578.245630082",
#               "miles": "9274324.2657038516"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-05": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3426410?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3426410",
#         "neo_reference_id": "3426410",
#         "name": "(2008 QV11)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3426410",
#         "absolute_magnitude_h": 21.34,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1434019235,
#             "estimated_diameter_max": 0.320656449
#           },
#           "meters": {
#             "estimated_diameter_min": 143.4019234645,
#             "estimated_diameter_max": 320.6564489709
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0891057966,
#             "estimated_diameter_max": 0.1992466184
#           },
#           "feet": {
#             "estimated_diameter_min": 470.4787665793,
#             "estimated_diameter_max": 1052.0225040417
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 17:46",
#             "epoch_date_close_approach": 1780681560000,
#             "relative_velocity": {
#               "kilometers_per_second": "15.210565323",
#               "kilometers_per_hour": "54758.0351628068",
#               "miles_per_hour": "34024.513571023"
#             },
#             "miss_distance": {
#               "astronomical": "0.1257971117",
#               "lunar": "48.9350764513",
#               "kilometers": "18818979.962472079",
#               "miles": "11693571.9105455302"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3672459?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3672459",
#         "neo_reference_id": "3672459",
#         "name": "(2014 KG39)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3672459",
#         "absolute_magnitude_h": 25.0,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.02658,
#             "estimated_diameter_max": 0.0594346868
#           },
#           "meters": {
#             "estimated_diameter_min": 26.58,
#             "estimated_diameter_max": 59.4346868419
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0165160412,
#             "estimated_diameter_max": 0.0369309908
#           },
#           "feet": {
#             "estimated_diameter_min": 87.2047272,
#             "estimated_diameter_max": 194.9956979785
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 17:51",
#             "epoch_date_close_approach": 1780681860000,
#             "relative_velocity": {
#               "kilometers_per_second": "7.9943339813",
#               "kilometers_per_hour": "28779.6023328323",
#               "miles_per_hour": "17882.5256828646"
#             },
#             "miss_distance": {
#               "astronomical": "0.0889845978",
#               "lunar": "34.6150085442",
#               "kilometers": "13311906.293686686",
#               "miles": "8271635.0100848268"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3673916?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3673916",
#         "neo_reference_id": "3673916",
#         "name": "(2014 MG6)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3673916",
#         "absolute_magnitude_h": 26.2,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0152951935,
#             "estimated_diameter_max": 0.0342010925
#           },
#           "meters": {
#             "estimated_diameter_min": 15.2951935344,
#             "estimated_diameter_max": 34.201092472
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0095039897,
#             "estimated_diameter_max": 0.021251567
#           },
#           "feet": {
#             "estimated_diameter_min": 50.1810827555,
#             "estimated_diameter_max": 112.2083122258
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 09:19",
#             "epoch_date_close_approach": 1780651140000,
#             "relative_velocity": {
#               "kilometers_per_second": "8.3867031468",
#               "kilometers_per_hour": "30192.1313284423",
#               "miles_per_hour": "18760.2162690535"
#             },
#             "miss_distance": {
#               "astronomical": "0.138163619",
#               "lunar": "53.745647791",
#               "kilometers": "20668983.11389153",
#               "miles": "12843110.564021914"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3837643?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3837643",
#         "neo_reference_id": "3837643",
#         "name": "(2019 AX3)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3837643",
#         "absolute_magnitude_h": 27.5,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.008405334,
#             "estimated_diameter_max": 0.0187948982
#           },
#           "meters": {
#             "estimated_diameter_min": 8.4053340207,
#             "estimated_diameter_max": 18.7948982439
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0052228308,
#             "estimated_diameter_max": 0.0116786047
#           },
#           "feet": {
#             "estimated_diameter_min": 27.5765560686,
#             "estimated_diameter_max": 61.6630539546
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 22:42",
#             "epoch_date_close_approach": 1780699320000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.3988876083",
#               "kilometers_per_hour": "23035.9953897604",
#               "miles_per_hour": "14313.6716909319"
#             },
#             "miss_distance": {
#               "astronomical": "0.3986992814",
#               "lunar": "155.0940204646",
#               "kilometers": "59644563.267970618",
#               "miles": "37061413.0541578084"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3843278?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3843278",
#         "neo_reference_id": "3843278",
#         "name": "(2019 NX5)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843278",
#         "absolute_magnitude_h": 29.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0040230458,
#             "estimated_diameter_max": 0.0089958039
#           },
#           "meters": {
#             "estimated_diameter_min": 4.0230457983,
#             "estimated_diameter_max": 8.9958038817
#           },
#           "miles": {
#             "estimated_diameter_min": 0.002499804,
#             "estimated_diameter_max": 0.0055897317
#           },
#           "feet": {
#             "estimated_diameter_min": 13.198969577,
#             "estimated_diameter_max": 29.5137932072
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 19:36",
#             "epoch_date_close_approach": 1780688160000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.2248471175",
#               "kilometers_per_hour": "22409.4496228421",
#               "miles_per_hour": "13924.3605170377"
#             },
#             "miss_distance": {
#               "astronomical": "0.1414106347",
#               "lunar": "55.0087368983",
#               "kilometers": "21154729.746468089",
#               "miles": "13144939.5255100682"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": true,
#         "sentry_data": "http://api.nasa.gov/neo/rest/v1/neo/sentry/3843278?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#       }
#     ],
#     "2026-06-04": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3781045?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3781045",
#         "neo_reference_id": "3781045",
#         "name": "(2017 QM18)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3781045",
#         "absolute_magnitude_h": 18.6,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.5064714588,
#             "estimated_diameter_max": 1.1325046106
#           },
#           "meters": {
#             "estimated_diameter_min": 506.4714588346,
#             "estimated_diameter_max": 1132.5046106177
#           },
#           "miles": {
#             "estimated_diameter_min": 0.3147066768,
#             "estimated_diameter_max": 0.7037055224
#           },
#           "feet": {
#             "estimated_diameter_min": 1661.651821003,
#             "estimated_diameter_max": 3715.566426699
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-04",
#             "close_approach_date_full": "2026-Jun-04 23:44",
#             "epoch_date_close_approach": 1780616640000,
#             "relative_velocity": {
#               "kilometers_per_second": "21.2712053964",
#               "kilometers_per_hour": "76576.3394272042",
#               "miles_per_hour": "47581.5593513092"
#             },
#             "miss_distance": {
#               "astronomical": "0.2445272255",
#               "lunar": "95.1210907195",
#               "kilometers": "36580752.091809685",
#               "miles": "22730225.335296253"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3838892?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3838892",
#         "neo_reference_id": "3838892",
#         "name": "(2019 ER)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838892",
#         "absolute_magnitude_h": 27.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0101054342,
#             "estimated_diameter_max": 0.0225964377
#           },
#           "meters": {
#             "estimated_diameter_min": 10.1054341542,
#             "estimated_diameter_max": 22.5964377109
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0062792237,
#             "estimated_diameter_max": 0.0140407711
#           },
#           "feet": {
#             "estimated_diameter_min": 33.1543125905,
#             "estimated_diameter_max": 74.1352966996
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-04",
#             "close_approach_date_full": "2026-Jun-04 01:28",
#             "epoch_date_close_approach": 1780536480000,
#             "relative_velocity": {
#               "kilometers_per_second": "10.2856955523",
#               "kilometers_per_hour": "37028.5039881205",
#               "miles_per_hour": "23008.0723808408"
#             },
#             "miss_distance": {
#               "astronomical": "0.2527703793",
#               "lunar": "98.3276775477",
#               "kilometers": "37813910.342372091",
#               "miles": "23496474.3407572158"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ]
#   }
# }
# SUCCESS

# %%
import os
from dotenv import load_dotenv
import requests
import json


load_dotenv()
api_key=os.getenv("API_key")

url="https://api.nasa.gov/neo/rest/v1/feed"

params={
    "start_date":"2026-06-01",
    "end_date":"2026-06-07",
    "api_key":api_key
}

response=requests.get(url,params=params)



if response.status_code==200:
    
    data = response.json()
    print(json.dumps(data,indent=2))
    print("SUCCESS")
elif response.status_code==429:
    print("Rate limit hit")
elif response.status_code==500:
    print("Server down")
else:
    print(f"Unexpected error {response.status_code}")

for date in data["near_earth_objects"]:
    for asteroid in data["near_earth_objects"][date]:
        extracts={
            "id" : asteroid["id"],
            "name" : asteroid["name"],
            "absolute_magnitude" : asteroid["absolute_magnitude_h"],
            "velocity" : asteroid["velocity"],
            "diameter_min" : asteroid["diameter_min"],
            "diamtere_max" : asteroid["diameter_max"]
            "miss_distance_au" : asteroid["miss_distance_au"],
            "is_hazardous" : asteroid["is_potentially_hazardous_hazardous"]
        }
extracts_list=list((extracts))

filename="raw_data.json"

with open(filename,"w") as fp:
    json.dump(filename,fp)

# %%
import os
from dotenv import load_dotenv
import requests
import json


load_dotenv()
api_key=os.getenv("API_key")

url="https://api.nasa.gov/neo/rest/v1/feed"

params={
    "start_date":"2026-06-01",
    "end_date":"2026-06-07",
    "api_key":api_key
}

response=requests.get(url,params=params)



if response.status_code==200:
    
    data = response.json()
    print(json.dumps(data,indent=2))
    print("SUCCESS")
elif response.status_code==429:
    print("Rate limit hit")
elif response.status_code==500:
    print("Server down")
else:
    print(f"Unexpected error {response.status_code}")

all_asteroids=[]
for date in data["near_earth_objects"]:
    for asteroid in data["near_earth_objects"][date]:
        extracts={
            "id" : asteroid["id"],
            "name" : asteroid["name"],
            "absolute_magnitude" : asteroid["absolute_magnitude_h"],
            "velocity" : asteroid["close_approach_data"][0]["relative_velocity"]["kilometers_per_second"],
            "diameter_min" : asteroid["estimated_diameter"]["kilometers"]["estimated_diameter_min"],
            "diameter_max" : asteroid["estimated_diameter"]["kilometers"]["estimated_diameter_max"],
            "miss_distance_au" : asteroid["close_approach_data"][0]["miss_distance"]["astronomical"],
            "is_hazardous" : asteroid["is_potentially_hazardous_asteroid"]
        }
        all_asteroids.append(extracts)



with open(r"d:\Downloads\My code\NASA-Asteroid-Classifier\data\raw_data.json","w") as fp:
    json.dump(all_asteroids,fp,indent=2)
# Out:
# {
#   "links": {
#     "next": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2026-06-07&end_date=2026-06-13&detailed=false&api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW",
#     "previous": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2026-05-26&end_date=2026-06-01&detailed=false&api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW",
#     "self": "http://api.nasa.gov/neo/rest/v1/feed?start_date=2026-06-01&end_date=2026-06-07&detailed=false&api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#   },
#   "element_count": 30,
#   "near_earth_objects": {
#     "2026-06-03": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/2437844?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "2437844",
#         "neo_reference_id": "2437844",
#         "name": "437844 (1999 MN)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2437844",
#         "absolute_magnitude_h": 21.01,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1669379118,
#             "estimated_diameter_max": 0.3732845187
#           },
#           "meters": {
#             "estimated_diameter_min": 166.9379117726,
#             "estimated_diameter_max": 373.2845187454
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1037303772,
#             "estimated_diameter_max": 0.2319481747
#           },
#           "feet": {
#             "estimated_diameter_min": 547.69657846,
#             "estimated_diameter_max": 1224.6867804805
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-03",
#             "close_approach_date_full": "2026-Jun-03 06:26",
#             "epoch_date_close_approach": 1780467960000,
#             "relative_velocity": {
#               "kilometers_per_second": "20.5789449268",
#               "kilometers_per_hour": "74084.2017363763",
#               "miles_per_hour": "46033.0419066945"
#             },
#             "miss_distance": {
#               "astronomical": "0.1615567231",
#               "lunar": "62.8455652859",
#               "kilometers": "24168541.659939797",
#               "miles": "15017635.4104793186"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3698472?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3698472",
#         "neo_reference_id": "3698472",
#         "name": "(2014 WD201)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3698472",
#         "absolute_magnitude_h": 19.2,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3841978911,
#             "estimated_diameter_max": 0.8590926012
#           },
#           "meters": {
#             "estimated_diameter_min": 384.1978910643,
#             "estimated_diameter_max": 859.0926012318
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2387294278,
#             "estimated_diameter_max": 0.5338152287
#           },
#           "feet": {
#             "estimated_diameter_min": 1260.4918089193,
#             "estimated_diameter_max": 2818.5453698252
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-03",
#             "close_approach_date_full": "2026-Jun-03 11:45",
#             "epoch_date_close_approach": 1780487100000,
#             "relative_velocity": {
#               "kilometers_per_second": "19.974695315",
#               "kilometers_per_hour": "71908.9031340223",
#               "miles_per_hour": "44681.3959501374"
#             },
#             "miss_distance": {
#               "astronomical": "0.4448614167",
#               "lunar": "173.0510910963",
#               "kilometers": "66550320.383502429",
#               "miles": "41352451.5476503602"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3836085?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3836085",
#         "neo_reference_id": "3836085",
#         "name": "(2018 VQ3)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3836085",
#         "absolute_magnitude_h": 20.55,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.2063264836,
#             "estimated_diameter_max": 0.4613600429
#           },
#           "meters": {
#             "estimated_diameter_min": 206.3264835999,
#             "estimated_diameter_max": 461.3600428879
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1282052934,
#             "estimated_diameter_max": 0.2866757512
#           },
#           "feet": {
#             "estimated_diameter_min": 676.9241804539,
#             "estimated_diameter_max": 1513.6484831083
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-03",
#             "close_approach_date_full": "2026-Jun-03 02:52",
#             "epoch_date_close_approach": 1780455120000,
#             "relative_velocity": {
#               "kilometers_per_second": "18.3663159671",
#               "kilometers_per_hour": "66118.7374815604",
#               "miles_per_hour": "41083.6121868062"
#             },
#             "miss_distance": {
#               "astronomical": "0.149966159",
#               "lunar": "58.336835851",
#               "kilometers": "22434617.95848133",
#               "miles": "13940225.182569154"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3843765?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3843765",
#         "neo_reference_id": "3843765",
#         "name": "(2019 RH)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843765",
#         "absolute_magnitude_h": 26.0,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0167708462,
#             "estimated_diameter_max": 0.0375007522
#           },
#           "meters": {
#             "estimated_diameter_min": 16.7708462163,
#             "estimated_diameter_max": 37.5007521798
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0104209175,
#             "estimated_diameter_max": 0.0233018799
#           },
#           "feet": {
#             "estimated_diameter_min": 55.0224631002,
#             "estimated_diameter_max": 123.0339677816
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-03",
#             "close_approach_date_full": "2026-Jun-03 17:05",
#             "epoch_date_close_approach": 1780506300000,
#             "relative_velocity": {
#               "kilometers_per_second": "11.9809958403",
#               "kilometers_per_hour": "43131.585025102",
#               "miles_per_hour": "26800.2895951807"
#             },
#             "miss_distance": {
#               "astronomical": "0.4357877517",
#               "lunar": "169.5214354113",
#               "kilometers": "65192919.426408879",
#               "miles": "40509001.7042013702"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-02": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/2141531?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "2141531",
#         "neo_reference_id": "2141531",
#         "name": "141531 (2002 GB)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2141531",
#         "absolute_magnitude_h": 19.15,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3931470096,
#             "estimated_diameter_max": 0.8791034386
#           },
#           "meters": {
#             "estimated_diameter_min": 393.1470095751,
#             "estimated_diameter_max": 879.1034385607
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2442901505,
#             "estimated_diameter_max": 0.5462493827
#           },
#           "feet": {
#             "estimated_diameter_min": 1289.8524348944,
#             "estimated_diameter_max": 2884.1977253675
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 23:26",
#             "epoch_date_close_approach": 1780442760000,
#             "relative_velocity": {
#               "kilometers_per_second": "14.6036159258",
#               "kilometers_per_hour": "52573.0173327108",
#               "miles_per_hour": "32666.8284643169"
#             },
#             "miss_distance": {
#               "astronomical": "0.4665729321",
#               "lunar": "181.4968705869",
#               "kilometers": "69798316.841814627",
#               "miles": "43370662.9611387726"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3410171?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3410171",
#         "neo_reference_id": "3410171",
#         "name": "(2008 JV2)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3410171",
#         "absolute_magnitude_h": 24.7,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0305179233,
#             "estimated_diameter_max": 0.0682401509
#           },
#           "meters": {
#             "estimated_diameter_min": 30.5179232594,
#             "estimated_diameter_max": 68.2401509401
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0189629525,
#             "estimated_diameter_max": 0.0424024508
#           },
#           "feet": {
#             "estimated_diameter_min": 100.1244233463,
#             "estimated_diameter_max": 223.8850168104
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 23:16",
#             "epoch_date_close_approach": 1780442160000,
#             "relative_velocity": {
#               "kilometers_per_second": "22.5085098886",
#               "kilometers_per_hour": "81030.6355990453",
#               "miles_per_hour": "50349.2857698624"
#             },
#             "miss_distance": {
#               "astronomical": "0.4992354475",
#               "lunar": "194.2025890775",
#               "kilometers": "74684559.574496825",
#               "miles": "46406833.406133185"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3428531?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3428531",
#         "neo_reference_id": "3428531",
#         "name": "(2008 SY150)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3428531",
#         "absolute_magnitude_h": 24.7,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0305179233,
#             "estimated_diameter_max": 0.0682401509
#           },
#           "meters": {
#             "estimated_diameter_min": 30.5179232594,
#             "estimated_diameter_max": 68.2401509401
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0189629525,
#             "estimated_diameter_max": 0.0424024508
#           },
#           "feet": {
#             "estimated_diameter_min": 100.1244233463,
#             "estimated_diameter_max": 223.8850168104
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 23:40",
#             "epoch_date_close_approach": 1780443600000,
#             "relative_velocity": {
#               "kilometers_per_second": "10.531450981",
#               "kilometers_per_hour": "37913.2235314312",
#               "miles_per_hour": "23557.802699294"
#             },
#             "miss_distance": {
#               "astronomical": "0.1453270055",
#               "lunar": "56.5322051395",
#               "kilometers": "21740610.476278285",
#               "miles": "13508988.929818933"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3553284?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3553284",
#         "neo_reference_id": "3553284",
#         "name": "(2010 XD25)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3553284",
#         "absolute_magnitude_h": 20.76,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1873074177,
#             "estimated_diameter_max": 0.4188321187
#           },
#           "meters": {
#             "estimated_diameter_min": 187.3074177315,
#             "estimated_diameter_max": 418.8321187375
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1163873975,
#             "estimated_diameter_max": 0.2602501325
#           },
#           "feet": {
#             "estimated_diameter_min": 614.5256683901,
#             "estimated_diameter_max": 1374.1211684388
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 07:01",
#             "epoch_date_close_approach": 1780383660000,
#             "relative_velocity": {
#               "kilometers_per_second": "29.0690868658",
#               "kilometers_per_hour": "104648.7127168764",
#               "miles_per_hour": "65024.6404101058"
#             },
#             "miss_distance": {
#               "astronomical": "0.4222820639",
#               "lunar": "164.2677228571",
#               "kilometers": "63172497.298643893",
#               "miles": "39253569.6091680034"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3579625?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3579625",
#         "neo_reference_id": "3579625",
#         "name": "(2011 SF108)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3579625",
#         "absolute_magnitude_h": 20.06,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.2585562121,
#             "estimated_diameter_max": 0.5781492662
#           },
#           "meters": {
#             "estimated_diameter_min": 258.5562120799,
#             "estimated_diameter_max": 578.1492662155
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1606593321,
#             "estimated_diameter_max": 0.3592451877
#           },
#           "feet": {
#             "estimated_diameter_min": 848.2815628403,
#             "estimated_diameter_max": 1896.8152385706
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 18:53",
#             "epoch_date_close_approach": 1780426380000,
#             "relative_velocity": {
#               "kilometers_per_second": "15.6630725114",
#               "kilometers_per_hour": "56387.0610409745",
#               "miles_per_hour": "35036.7269007099"
#             },
#             "miss_distance": {
#               "astronomical": "0.4377050035",
#               "lunar": "170.2672463615",
#               "kilometers": "65479736.211942545",
#               "miles": "40687221.390575321"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3678630?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3678630",
#         "neo_reference_id": "3678630",
#         "name": "(2014 OL339)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3678630",
#         "absolute_magnitude_h": 22.78,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0738847787,
#             "estimated_diameter_max": 0.1652113876
#           },
#           "meters": {
#             "estimated_diameter_min": 73.884778657,
#             "estimated_diameter_max": 165.2113875797
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0459098588,
#             "estimated_diameter_max": 0.1026575651
#           },
#           "feet": {
#             "estimated_diameter_min": 242.4041372092,
#             "estimated_diameter_max": 542.0321288269
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 18:15",
#             "epoch_date_close_approach": 1780424100000,
#             "relative_velocity": {
#               "kilometers_per_second": "11.8622601181",
#               "kilometers_per_hour": "42704.1364253353",
#               "miles_per_hour": "26534.6896582868"
#             },
#             "miss_distance": {
#               "astronomical": "0.3412333442",
#               "lunar": "132.7397708938",
#               "kilometers": "51047781.465296854",
#               "miles": "31719620.5441864252"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3884238?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3884238",
#         "neo_reference_id": "3884238",
#         "name": "(2019 US10)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3884238",
#         "absolute_magnitude_h": 20.68,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1943367684,
#             "estimated_diameter_max": 0.4345502246
#           },
#           "meters": {
#             "estimated_diameter_min": 194.3367683899,
#             "estimated_diameter_max": 434.5502246474
#           },
#           "miles": {
#             "estimated_diameter_min": 0.1207552321,
#             "estimated_diameter_max": 0.2700169076
#           },
#           "feet": {
#             "estimated_diameter_min": 637.5878432043,
#             "estimated_diameter_max": 1425.6897590323
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-02",
#             "close_approach_date_full": "2026-Jun-02 02:32",
#             "epoch_date_close_approach": 1780367520000,
#             "relative_velocity": {
#               "kilometers_per_second": "14.2682462176",
#               "kilometers_per_hour": "51365.6863835191",
#               "miles_per_hour": "31916.6399642483"
#             },
#             "miss_distance": {
#               "astronomical": "0.3893958238",
#               "lunar": "151.4749754582",
#               "kilometers": "58252785.827375306",
#               "miles": "36196602.6543629828"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-01": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3774363?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3774363",
#         "neo_reference_id": "3774363",
#         "name": "(2017 HE49)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3774363",
#         "absolute_magnitude_h": 23.7,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0483676488,
#             "estimated_diameter_max": 0.1081533507
#           },
#           "meters": {
#             "estimated_diameter_min": 48.3676488219,
#             "estimated_diameter_max": 108.1533506775
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0300542543,
#             "estimated_diameter_max": 0.0672033557
#           },
#           "feet": {
#             "estimated_diameter_min": 158.6865169607,
#             "estimated_diameter_max": 354.8338390368
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-01",
#             "close_approach_date_full": "2026-Jun-01 10:15",
#             "epoch_date_close_approach": 1780308900000,
#             "relative_velocity": {
#               "kilometers_per_second": "4.4192793323",
#               "kilometers_per_hour": "15909.4055963739",
#               "miles_per_hour": "9885.4859384802"
#             },
#             "miss_distance": {
#               "astronomical": "0.1707317045",
#               "lunar": "66.4146330505",
#               "kilometers": "25541099.334669415",
#               "miles": "15870503.201551327"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3795028?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3795028",
#         "neo_reference_id": "3795028",
#         "name": "(2017 YV3)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3795028",
#         "absolute_magnitude_h": 25.0,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.02658,
#             "estimated_diameter_max": 0.0594346868
#           },
#           "meters": {
#             "estimated_diameter_min": 26.58,
#             "estimated_diameter_max": 59.4346868419
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0165160412,
#             "estimated_diameter_max": 0.0369309908
#           },
#           "feet": {
#             "estimated_diameter_min": 87.2047272,
#             "estimated_diameter_max": 194.9956979785
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-01",
#             "close_approach_date_full": "2026-Jun-01 16:42",
#             "epoch_date_close_approach": 1780332120000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.5515259013",
#               "kilometers_per_hour": "23585.4932445653",
#               "miles_per_hour": "14655.1082885467"
#             },
#             "miss_distance": {
#               "astronomical": "0.2627561175",
#               "lunar": "102.2121297075",
#               "kilometers": "39307755.507469725",
#               "miles": "24424706.683643205"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3836092?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3836092",
#         "neo_reference_id": "3836092",
#         "name": "(2018 VO3)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3836092",
#         "absolute_magnitude_h": 27.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0101054342,
#             "estimated_diameter_max": 0.0225964377
#           },
#           "meters": {
#             "estimated_diameter_min": 10.1054341542,
#             "estimated_diameter_max": 22.5964377109
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0062792237,
#             "estimated_diameter_max": 0.0140407711
#           },
#           "feet": {
#             "estimated_diameter_min": 33.1543125905,
#             "estimated_diameter_max": 74.1352966996
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-01",
#             "close_approach_date_full": "2026-Jun-01 10:29",
#             "epoch_date_close_approach": 1780309740000,
#             "relative_velocity": {
#               "kilometers_per_second": "5.4485213414",
#               "kilometers_per_hour": "19614.6768290682",
#               "miles_per_hour": "12187.7973885952"
#             },
#             "miss_distance": {
#               "astronomical": "0.2646063846",
#               "lunar": "102.9318836094",
#               "kilometers": "39584551.524560802",
#               "miles": "24596699.7532389876"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-07": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3336867?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3336867",
#         "neo_reference_id": "3336867",
#         "name": "(2006 MB)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3336867",
#         "absolute_magnitude_h": 22.59,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0806408277,
#             "estimated_diameter_max": 0.1803183724
#           },
#           "meters": {
#             "estimated_diameter_min": 80.6408276759,
#             "estimated_diameter_max": 180.3183724451
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0501078717,
#             "estimated_diameter_max": 0.1120446074
#           },
#           "feet": {
#             "estimated_diameter_min": 264.5696530721,
#             "estimated_diameter_max": 591.5957290529
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-07",
#             "close_approach_date_full": "2026-Jun-07 09:44",
#             "epoch_date_close_approach": 1780825440000,
#             "relative_velocity": {
#               "kilometers_per_second": "7.3333208459",
#               "kilometers_per_hour": "26399.9550453693",
#               "miles_per_hour": "16403.905400274"
#             },
#             "miss_distance": {
#               "astronomical": "0.1009440019",
#               "lunar": "39.2672167391",
#               "kilometers": "15101007.673515953",
#               "miles": "9383331.0574800314"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3802390?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3802390",
#         "neo_reference_id": "3802390",
#         "name": "(2018 GE)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3802390",
#         "absolute_magnitude_h": 27.5,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.008405334,
#             "estimated_diameter_max": 0.0187948982
#           },
#           "meters": {
#             "estimated_diameter_min": 8.4053340207,
#             "estimated_diameter_max": 18.7948982439
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0052228308,
#             "estimated_diameter_max": 0.0116786047
#           },
#           "feet": {
#             "estimated_diameter_min": 27.5765560686,
#             "estimated_diameter_max": 61.6630539546
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-07",
#             "close_approach_date_full": "2026-Jun-07 14:05",
#             "epoch_date_close_approach": 1780841100000,
#             "relative_velocity": {
#               "kilometers_per_second": "3.0944487127",
#               "kilometers_per_hour": "11140.0153655584",
#               "miles_per_hour": "6921.9723253382"
#             },
#             "miss_distance": {
#               "astronomical": "0.0418956903",
#               "lunar": "16.2974235267",
#               "kilometers": "6267506.031059661",
#               "miles": "3894447.6597628818"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": true,
#         "sentry_data": "http://api.nasa.gov/neo/rest/v1/neo/sentry/3802390?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3838104?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3838104",
#         "neo_reference_id": "3838104",
#         "name": "(2019 CH1)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838104",
#         "absolute_magnitude_h": 21.22,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1515496636,
#             "estimated_diameter_max": 0.3388753497
#           },
#           "meters": {
#             "estimated_diameter_min": 151.5496635722,
#             "estimated_diameter_max": 338.8753497147
#           },
#           "miles": {
#             "estimated_diameter_min": 0.094168566,
#             "estimated_diameter_max": 0.2105673149
#           },
#           "feet": {
#             "estimated_diameter_min": 497.2101982343,
#             "estimated_diameter_max": 1111.795802358
#           }
#         },
#         "is_potentially_hazardous_asteroid": true,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-07",
#             "close_approach_date_full": "2026-Jun-07 08:14",
#             "epoch_date_close_approach": 1780820040000,
#             "relative_velocity": {
#               "kilometers_per_second": "21.8900781055",
#               "kilometers_per_hour": "78804.2811796736",
#               "miles_per_hour": "48965.9157141144"
#             },
#             "miss_distance": {
#               "astronomical": "0.1578444104",
#               "lunar": "61.4014756456",
#               "kilometers": "23613187.587245848",
#               "miles": "14672554.3913267824"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3991612?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3991612",
#         "neo_reference_id": "3991612",
#         "name": "(2020 DJ)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3991612",
#         "absolute_magnitude_h": 26.2,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0152951935,
#             "estimated_diameter_max": 0.0342010925
#           },
#           "meters": {
#             "estimated_diameter_min": 15.2951935344,
#             "estimated_diameter_max": 34.201092472
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0095039897,
#             "estimated_diameter_max": 0.021251567
#           },
#           "feet": {
#             "estimated_diameter_min": 50.1810827555,
#             "estimated_diameter_max": 112.2083122258
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-07",
#             "close_approach_date_full": "2026-Jun-07 05:49",
#             "epoch_date_close_approach": 1780811340000,
#             "relative_velocity": {
#               "kilometers_per_second": "5.4696246188",
#               "kilometers_per_hour": "19690.6486275341",
#               "miles_per_hour": "12235.0033097031"
#             },
#             "miss_distance": {
#               "astronomical": "0.4019967606",
#               "lunar": "156.3767398734",
#               "kilometers": "60137859.132659922",
#               "miles": "37367932.8909620436"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-06": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/2478784?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "2478784",
#         "neo_reference_id": "2478784",
#         "name": "478784 (2012 UV136)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2478784",
#         "absolute_magnitude_h": 25.6,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0201629919,
#             "estimated_diameter_max": 0.0450858206
#           },
#           "meters": {
#             "estimated_diameter_min": 20.1629919443,
#             "estimated_diameter_max": 45.0858206172
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0125286985,
#             "estimated_diameter_max": 0.0280150214
#           },
#           "feet": {
#             "estimated_diameter_min": 66.1515504905,
#             "estimated_diameter_max": 147.9193637137
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 16:56",
#             "epoch_date_close_approach": 1780764960000,
#             "relative_velocity": {
#               "kilometers_per_second": "16.0783776861",
#               "kilometers_per_hour": "57882.1596699298",
#               "miles_per_hour": "35965.7230460183"
#             },
#             "miss_distance": {
#               "astronomical": "0.4165825079",
#               "lunar": "162.0505955731",
#               "kilometers": "62319855.861098173",
#               "miles": "38723762.7873458674"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3304382?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3304382",
#         "neo_reference_id": "3304382",
#         "name": "(2005 WR2)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3304382",
#         "absolute_magnitude_h": 19.52,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3315545381,
#             "estimated_diameter_max": 0.7413784854
#           },
#           "meters": {
#             "estimated_diameter_min": 331.5545380858,
#             "estimated_diameter_max": 741.3784854083
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2060183749,
#             "estimated_diameter_max": 0.4606710909
#           },
#           "feet": {
#             "estimated_diameter_min": 1087.7773907333,
#             "estimated_diameter_max": 2432.3441900671
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 20:30",
#             "epoch_date_close_approach": 1780777800000,
#             "relative_velocity": {
#               "kilometers_per_second": "14.4751788763",
#               "kilometers_per_hour": "52110.6439547264",
#               "miles_per_hour": "32379.5276284243"
#             },
#             "miss_distance": {
#               "astronomical": "0.0997712288",
#               "lunar": "38.8110080032",
#               "kilometers": "14925563.315762656",
#               "miles": "9274314.9887144128"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3644087?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3644087",
#         "neo_reference_id": "3644087",
#         "name": "(2013 MR)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3644087",
#         "absolute_magnitude_h": 21.62,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1260535197,
#             "estimated_diameter_max": 0.2818642388
#           },
#           "meters": {
#             "estimated_diameter_min": 126.0535196822,
#             "estimated_diameter_max": 281.8642388124
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0783260016,
#             "estimated_diameter_max": 0.1751422639
#           },
#           "feet": {
#             "estimated_diameter_min": 413.5614295141,
#             "estimated_diameter_max": 924.7514692654
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 08:36",
#             "epoch_date_close_approach": 1780734960000,
#             "relative_velocity": {
#               "kilometers_per_second": "17.3402140505",
#               "kilometers_per_hour": "62424.7705816326",
#               "miles_per_hour": "38788.3248094594"
#             },
#             "miss_distance": {
#               "astronomical": "0.1122679098",
#               "lunar": "43.6722169122",
#               "kilometers": "16795040.175432126",
#               "miles": "10435954.0433942988"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3892162?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3892162",
#         "neo_reference_id": "3892162",
#         "name": "(2019 UK13)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3892162",
#         "absolute_magnitude_h": 24.71,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0303777061,
#             "estimated_diameter_max": 0.0679266159
#           },
#           "meters": {
#             "estimated_diameter_min": 30.3777061387,
#             "estimated_diameter_max": 67.9266159267
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0188758256,
#             "estimated_diameter_max": 0.0422076293
#           },
#           "feet": {
#             "estimated_diameter_min": 99.6643934081,
#             "estimated_diameter_max": 222.8563585969
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 06:51",
#             "epoch_date_close_approach": 1780728660000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.0591186198",
#               "kilometers_per_hour": "21812.8270311597",
#               "miles_per_hour": "13553.6424405558"
#             },
#             "miss_distance": {
#               "astronomical": "0.3950304344",
#               "lunar": "153.6668389816",
#               "kilometers": "59095711.571414728",
#               "miles": "36720372.4241821264"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/2662203?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "2662203",
#         "neo_reference_id": "2662203",
#         "name": "662203 (2005 WR2)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2662203",
#         "absolute_magnitude_h": 19.47,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.3392774354,
#             "estimated_diameter_max": 0.7586474087
#           },
#           "meters": {
#             "estimated_diameter_min": 339.2774353821,
#             "estimated_diameter_max": 758.6474087461
#           },
#           "miles": {
#             "estimated_diameter_min": 0.2108171593,
#             "estimated_diameter_max": 0.471401499
#           },
#           "feet": {
#             "estimated_diameter_min": 1113.1149810989,
#             "estimated_diameter_max": 2489.0007645105
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-06",
#             "close_approach_date_full": "2026-Jun-06 20:30",
#             "epoch_date_close_approach": 1780777800000,
#             "relative_velocity": {
#               "kilometers_per_second": "14.4751730434",
#               "kilometers_per_hour": "52110.622956137",
#               "miles_per_hour": "32379.5145807175"
#             },
#             "miss_distance": {
#               "astronomical": "0.0997713286",
#               "lunar": "38.8110468254",
#               "kilometers": "14925578.245630082",
#               "miles": "9274324.2657038516"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ],
#     "2026-06-05": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3426410?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3426410",
#         "neo_reference_id": "3426410",
#         "name": "(2008 QV11)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3426410",
#         "absolute_magnitude_h": 21.34,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.1434019235,
#             "estimated_diameter_max": 0.320656449
#           },
#           "meters": {
#             "estimated_diameter_min": 143.4019234645,
#             "estimated_diameter_max": 320.6564489709
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0891057966,
#             "estimated_diameter_max": 0.1992466184
#           },
#           "feet": {
#             "estimated_diameter_min": 470.4787665793,
#             "estimated_diameter_max": 1052.0225040417
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 17:46",
#             "epoch_date_close_approach": 1780681560000,
#             "relative_velocity": {
#               "kilometers_per_second": "15.210565323",
#               "kilometers_per_hour": "54758.0351628068",
#               "miles_per_hour": "34024.513571023"
#             },
#             "miss_distance": {
#               "astronomical": "0.1257971117",
#               "lunar": "48.9350764513",
#               "kilometers": "18818979.962472079",
#               "miles": "11693571.9105455302"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3672459?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3672459",
#         "neo_reference_id": "3672459",
#         "name": "(2014 KG39)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3672459",
#         "absolute_magnitude_h": 25.0,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.02658,
#             "estimated_diameter_max": 0.0594346868
#           },
#           "meters": {
#             "estimated_diameter_min": 26.58,
#             "estimated_diameter_max": 59.4346868419
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0165160412,
#             "estimated_diameter_max": 0.0369309908
#           },
#           "feet": {
#             "estimated_diameter_min": 87.2047272,
#             "estimated_diameter_max": 194.9956979785
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 17:51",
#             "epoch_date_close_approach": 1780681860000,
#             "relative_velocity": {
#               "kilometers_per_second": "7.9943339813",
#               "kilometers_per_hour": "28779.6023328323",
#               "miles_per_hour": "17882.5256828646"
#             },
#             "miss_distance": {
#               "astronomical": "0.0889845978",
#               "lunar": "34.6150085442",
#               "kilometers": "13311906.293686686",
#               "miles": "8271635.0100848268"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3673916?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3673916",
#         "neo_reference_id": "3673916",
#         "name": "(2014 MG6)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3673916",
#         "absolute_magnitude_h": 26.2,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0152951935,
#             "estimated_diameter_max": 0.0342010925
#           },
#           "meters": {
#             "estimated_diameter_min": 15.2951935344,
#             "estimated_diameter_max": 34.201092472
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0095039897,
#             "estimated_diameter_max": 0.021251567
#           },
#           "feet": {
#             "estimated_diameter_min": 50.1810827555,
#             "estimated_diameter_max": 112.2083122258
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 09:19",
#             "epoch_date_close_approach": 1780651140000,
#             "relative_velocity": {
#               "kilometers_per_second": "8.3867031468",
#               "kilometers_per_hour": "30192.1313284423",
#               "miles_per_hour": "18760.2162690535"
#             },
#             "miss_distance": {
#               "astronomical": "0.138163619",
#               "lunar": "53.745647791",
#               "kilometers": "20668983.11389153",
#               "miles": "12843110.564021914"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3837643?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3837643",
#         "neo_reference_id": "3837643",
#         "name": "(2019 AX3)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3837643",
#         "absolute_magnitude_h": 27.5,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.008405334,
#             "estimated_diameter_max": 0.0187948982
#           },
#           "meters": {
#             "estimated_diameter_min": 8.4053340207,
#             "estimated_diameter_max": 18.7948982439
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0052228308,
#             "estimated_diameter_max": 0.0116786047
#           },
#           "feet": {
#             "estimated_diameter_min": 27.5765560686,
#             "estimated_diameter_max": 61.6630539546
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 22:42",
#             "epoch_date_close_approach": 1780699320000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.3988876083",
#               "kilometers_per_hour": "23035.9953897604",
#               "miles_per_hour": "14313.6716909319"
#             },
#             "miss_distance": {
#               "astronomical": "0.3986992814",
#               "lunar": "155.0940204646",
#               "kilometers": "59644563.267970618",
#               "miles": "37061413.0541578084"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3843278?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3843278",
#         "neo_reference_id": "3843278",
#         "name": "(2019 NX5)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3843278",
#         "absolute_magnitude_h": 29.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0040230458,
#             "estimated_diameter_max": 0.0089958039
#           },
#           "meters": {
#             "estimated_diameter_min": 4.0230457983,
#             "estimated_diameter_max": 8.9958038817
#           },
#           "miles": {
#             "estimated_diameter_min": 0.002499804,
#             "estimated_diameter_max": 0.0055897317
#           },
#           "feet": {
#             "estimated_diameter_min": 13.198969577,
#             "estimated_diameter_max": 29.5137932072
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-05",
#             "close_approach_date_full": "2026-Jun-05 19:36",
#             "epoch_date_close_approach": 1780688160000,
#             "relative_velocity": {
#               "kilometers_per_second": "6.2248471175",
#               "kilometers_per_hour": "22409.4496228421",
#               "miles_per_hour": "13924.3605170377"
#             },
#             "miss_distance": {
#               "astronomical": "0.1414106347",
#               "lunar": "55.0087368983",
#               "kilometers": "21154729.746468089",
#               "miles": "13144939.5255100682"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": true,
#         "sentry_data": "http://api.nasa.gov/neo/rest/v1/neo/sentry/3843278?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#       }
#     ],
#     "2026-06-04": [
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3781045?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3781045",
#         "neo_reference_id": "3781045",
#         "name": "(2017 QM18)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3781045",
#         "absolute_magnitude_h": 18.6,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.5064714588,
#             "estimated_diameter_max": 1.1325046106
#           },
#           "meters": {
#             "estimated_diameter_min": 506.4714588346,
#             "estimated_diameter_max": 1132.5046106177
#           },
#           "miles": {
#             "estimated_diameter_min": 0.3147066768,
#             "estimated_diameter_max": 0.7037055224
#           },
#           "feet": {
#             "estimated_diameter_min": 1661.651821003,
#             "estimated_diameter_max": 3715.566426699
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-04",
#             "close_approach_date_full": "2026-Jun-04 23:44",
#             "epoch_date_close_approach": 1780616640000,
#             "relative_velocity": {
#               "kilometers_per_second": "21.2712053964",
#               "kilometers_per_hour": "76576.3394272042",
#               "miles_per_hour": "47581.5593513092"
#             },
#             "miss_distance": {
#               "astronomical": "0.2445272255",
#               "lunar": "95.1210907195",
#               "kilometers": "36580752.091809685",
#               "miles": "22730225.335296253"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       },
#       {
#         "links": {
#           "self": "http://api.nasa.gov/neo/rest/v1/neo/3838892?api_key=OIu0Uod9bK1n0jCGW1WUpLAbMFa1YbIIsImeQWZW"
#         },
#         "id": "3838892",
#         "neo_reference_id": "3838892",
#         "name": "(2019 ER)",
#         "nasa_jpl_url": "https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838892",
#         "absolute_magnitude_h": 27.1,
#         "estimated_diameter": {
#           "kilometers": {
#             "estimated_diameter_min": 0.0101054342,
#             "estimated_diameter_max": 0.0225964377
#           },
#           "meters": {
#             "estimated_diameter_min": 10.1054341542,
#             "estimated_diameter_max": 22.5964377109
#           },
#           "miles": {
#             "estimated_diameter_min": 0.0062792237,
#             "estimated_diameter_max": 0.0140407711
#           },
#           "feet": {
#             "estimated_diameter_min": 33.1543125905,
#             "estimated_diameter_max": 74.1352966996
#           }
#         },
#         "is_potentially_hazardous_asteroid": false,
#         "close_approach_data": [
#           {
#             "close_approach_date": "2026-06-04",
#             "close_approach_date_full": "2026-Jun-04 01:28",
#             "epoch_date_close_approach": 1780536480000,
#             "relative_velocity": {
#               "kilometers_per_second": "10.2856955523",
#               "kilometers_per_hour": "37028.5039881205",
#               "miles_per_hour": "23008.0723808408"
#             },
#             "miss_distance": {
#               "astronomical": "0.2527703793",
#               "lunar": "98.3276775477",
#               "kilometers": "37813910.342372091",
#               "miles": "23496474.3407572158"
#             },
#             "orbiting_body": "Earth"
#           }
#         ],
#         "is_sentry_object": false
#       }
#     ]
#   }
# }
# SUCCESS

# %%
import os
from dotenv import load_dotenv
import json
import requests
import time
from datetime import timedelta, date


load_dotenv()
API_key = os.getenv("API_key")

url = "https://api.nasa.gov/neo/rest/v1/feed"

all_asteroids=[]

start_date = date(2025,7,1)
end_date = date(2026,7,1)
current = start_date

while current<end_date:
    weekend = current + timedelta(days=7)
    params = {
        "start_date" : current ,
        "end_date" : weekend ,
        "api_key" : API_key
    }
    response=requests.get(url,params=params)

    if response.status_code == 200:
        data=response.json()
        for date in data["near_earth_objects"]:
            for asteroid in data["near_earth_objects"][date]:
                extracts ={
                    "id" : asteroid["id"],
                    "name" : asteroid["name"],
                    "absolute_magnitude" : asteroid["absolute_magnitude_h"],
                    "velocity" : asteroid["close_approach_data"][0]["relative_velocity"]["kilometers_per_second"],
                    "diameter_min" : asteroid["estimated_diameter"]["kilometers"]["estimated_diameter_min"],
                    "diameter_max" : asteroid["estimated_diameter"]["kilometers"]["estimated_diameter_max"],
                    "miss_distance_au" : asteroid["close_approach_data"][0]["miss_distance"]["astronomical"],
                    "is_hazardous" : asteroid["is_potentially_hazardous_asteroid"]
                }
                all_asteroids.append(extracts)
        
        print("SUCCESS")
    elif response.status_code == 429:
        print("Rate limit hit")
    elif response.status_code == 500:
        print("Server down")
    else:
        print(f"Unexpected Error {response.status_code}")
    time.sleep(1)
    current=current + timedelta(days=7)
print(f"Total asteroids collected: {len(all_asteroids)}")

with open(r"d:\Downloads\My code\NASA-Asteroid-Classifier\data\raw_data.json","w") as fp:
    json.dump(all_asteroids,fp,indent=2)
# Out:
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# SUCCESS
# Total asteroids collected: 1759
